# %%
import sys
import torch

def print_python_version_number():
    version_info = sys.version_info
    version_number = f"{version_info.major}.{version_info.minor}.{version_info.micro}"
    print(f"Current Python version: {version_number}")

if __name__ == "__main__":
    print_python_version_number()
# Out:
# Current Python version: 3.10.16

# %%
print('test')
# Out:
# test
